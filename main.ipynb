# %% [markdown]
# ## Bank Card Fraud Detection - Unsupervised Anomaly Detection
#
# The dataset used for training the model has 284315 non-fraud data points and 492 fraud data points.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# scikit-learn
from sklearn.manifold import TSNE
from sklearn.model_selection import train_test_split
from sklearn.ensemble import IsolationForest
from sklearn.svm import OneClassSVM
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# evaluation metrics
from sklearn.metrics import classification_report, accuracy_score
from sklearn.metrics import average_precision_score
from sklearn.metrics import roc_auc_score

# scaling
from sklearn.preprocessing import StandardScaler

# autoencoder
import tensorflow as tf
from tensorflow import keras

# deep learning
from keras.models import Model, Sequential
from keras import regularizers
from keras.layers import (
    Input,
    Conv1D,
    MaxPooling1D,
    Dense,
    Flatten,
    Dropout,
    BatchNormalization,
)
from keras.optimizers import Adam

# code formatter
# %load_ext nb_black

# %% [markdown]
# ## Reading the dataset and running some stats

# %%
# reading the input dataset
df = pd.read_csv("data/creditcard.csv")

# %%
# checking the number of rows and columns
df.shape
# Out:
# (284807, 31)

# %%
# checking the first 5 records
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
# checking for null values
df.isnull().any()
# Out:
# Time      False
# V1        False
# V2        False
# V3        False
# V4        False
# V5        False
# V6        False
# V7        False
# V8        False
# V9        False
# V10       False
# V11       False
# V12       False
# V13       False
# V14       False
# V15       False
# V16       False
# V17       False
# V18       False
# V19       False
# V20       False
# V21       False
# V22       False
# V23       False
# V24       False
# V25       False
# V26       False
# V27       False
# V28       False
# Amount    False
# Class     False
# dtype: bool

# %%
# checking for data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %% [markdown]
# The data types look correct!

# %%
# checking the data stats
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.165980e-15  3.416908e-16 -1.373150e-15  2.086869e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.490107e-15 -5.556467e-16  1.177556e-16 -2.406455e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.656562e-16 -3.444850e-16  2.578648e-16  4.471968e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   5.340915e-16  1.687098e-15 -3.666453e-16 -1.220404e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# checking the count for each class
df["Class"].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# The counts for each of the 2 target class shows a highly imbalanced data.

# %%
# plotting the class count to show imbalanced dataset

class_name = ["non-fraud", "fraud"]
class_count = pd.value_counts(df["Class"], sort=True)
class_count.plot(kind="bar", rot=0, color=["blue", "red"])
plt.xticks(range(2), class_name)
plt.xlabel("Class")
plt.ylabel("Frequency")
plt.title("Plot showing imbalanced data")
plt.show()

# %% [markdown]
# The bar graph shows highly imbalanced dataset. There are 284315 data points for non-fraud data as compared to only 492 data points for fraud data.

# %%
# checking for correlations

fig = plt.figure(figsize=(10, 8))
sns.heatmap(df.corr())
plt.show()

# %% [markdown]
# The correlation plot shows no presence of multi collinearity amongst V1 to V28 features (PCA components). Some of these features does show high correlation with the target class (Class) and independent features - Time and Amount. The target class does not seem to have any correlation with Time and Amount.

# %%
# setting up separate dataframes for fraud and non_fraud data for detailed analysis and comparison

fraud_data = df[df["Class"] == 1].reset_index(drop=True)
non_fraud_data = df[df["Class"] == 0].reset_index(drop=True)

print("Fraud Data Shape: ", fraud_data.shape)
print("Non-Fraud Data Shape: ", non_fraud_data.shape)
# Out:
# Fraud Data Shape:  (492, 31)
# Non-Fraud Data Shape:  (284315, 31)

# %%
fraud_data.head()
# Out:
#      Time        V1        V2        V3        V4        V5        V6  \
# 0   406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 1   472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 2  4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 3  6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 4  7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0 -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211  0.320198
# 1  0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966 -0.293803
# 2  0.562320 -0.399147 -0.238253  ... -0.294166 -0.932391  0.172726 -0.087330
# 3 -3.496197 -0.248778 -0.247768  ...  0.573574  0.176968 -0.436207 -0.053502
# 4  1.713445 -0.496358 -1.282858  ... -0.379068 -0.704181 -0.656805 -1.632653
#
#         V25       V26       V27       V28  Amount  Class
# 0  0.044519  0.177840  0.261145 -0.143276    0.00      1
# 1  0.279798 -0.145362 -0.252773  0.035764  529.00      1
# 2 -0.156114 -0.542628  0.039566 -0.153029  239.93      1
# 3  0.252405 -0.657488 -0.827136  0.849573   59.00      1
# 4  1.488901  0.566797 -0.010016  0.146793    1.00      1
#
# [5 rows x 31 columns]

# %%
non_fraud_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
# Amount distribution comparison (line plot)

fig = plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(fraud_data["Amount"], color="red")
plt.title("Fraud Amount Distribution")
plt.xlabel("Frequency")
plt.ylabel("Amount")

plt.subplot(1, 2, 2)
plt.plot(non_fraud_data["Amount"], color="blue")
plt.title("Non-Fraud Amount Distribution")
plt.xlabel("Frequency")
plt.ylabel("Amount")

plt.show()

# %%
# Amount distribution comparison (histogram)

fig = plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.hist(fraud_data["Amount"], color="red")
plt.title("Fraud Amount Distribution")
plt.xlabel("Amount")
plt.ylabel("Frequency")

plt.subplot(1, 2, 2)
plt.hist(non_fraud_data["Amount"], color="blue")
plt.title("Non-Fraud Amount Distribution")
plt.xlabel("Amount")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# In the above two plots, we can see that for the Fraud data, majority (more than 400 times) of the times the transaction amount is less than 250 and only a small number (5 to 10) of times the transaction amount is between 1000 to 2500. The max amount is less than 2500.
#
# Whereas, for the non-fraud data, almost all of the times, the transaction amount is between 0 and 2500 and a very few number of times, the amount is between 2500 and 5000. The max amount is a little over 5000.

# %%
# Time vs. Amount distribution comparison (scatter plot)

fig = plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.scatter(fraud_data["Time"], fraud_data["Amount"], color="red")
plt.title("Fraud Amount Distribution")
plt.xlabel("Time (seconds)")
plt.ylabel("Amount")

plt.subplot(1, 2, 2)
plt.scatter(non_fraud_data["Time"], non_fraud_data["Amount"], color="blue")
plt.title("Non-Fraud Amount Distribution")
plt.xlabel("Time (seconds)")
plt.ylabel("Amount")

plt.show()

# %% [markdown]
# Based on the above plot, time and amount doesn't seem to show any significant correlation.

# %% [markdown]
# ## Unsupervised Machine Learning Techniques for Anomaly Detection

# %%
# Since the dataset is too large, taking a sample from that data to train models
sampled_data = df.sample(frac=0.1, random_state=42)

print("Sampled Data Shape:", sampled_data.shape)
print("Target Class Value Count: ")
print(sampled_data["Class"].value_counts())
# Out:
# Sampled Data Shape: (28481, 31)
# Target Class Value Count:
# 0    28435
# 1       46
# Name: Class, dtype: int64

# %%
# splitting data into X and y

X = sampled_data.drop("Class", axis=1)
y = sampled_data["Class"]

print("X Shape: ", X.shape)
print("y Shape: ", y.shape)
print("========================================")
print("Target Class Value Count: ")
print("Normal Class: ", (y == 0).sum())
print("Fraud Class: ", (y == 1).sum())

fraud = sampled_data[sampled_data["Class"] == 1]
non_fraud = sampled_data[sampled_data["Class"] == 0]

outlier_fraction = len(fraud) / float(len(non_fraud))
print("========================================")
print("Fraud Fraction: ", outlier_fraction)
# Out:
# X Shape:  (28481, 30)
# y Shape:  (28481,)
# ========================================
# Target Class Value Count:
# Normal Class:  28435
# Fraud Class:  46
# ========================================
# Fraud Fraction:  0.001617724635132759

# %% [markdown]
# ## 1. Isolation Forest (Unsupervised Outlier Detection)
# Isolation tree is an unsupervised algorithm and therefore it does not need labels to identify the outlier/anomaly. It follows the following steps: Random and recursive partition of data is carried out, which is represented as a tree (random forest).

# %%
clf = IsolationForest(n_estimators=100, max_samples=len(X), random_state=42, contamination=outlier_fraction)

clf.fit(X)
y_pred = clf.predict(X)

print("Predicted Anomalous Data Points: ", len(y_pred[y_pred == -1]))
print("Predicted Non Anomalous Data Points: ", len(y_pred[y_pred == 1]))
print("=======================================================")

# replacing -1 by 1 and 1 by 0
y_pred[y_pred == 1] = 0
y_pred[y_pred == -1] = 1

# evaluation
print("Number of misclassified data points: ", (y_pred != y).sum())
print("\nAccuracy Score :", accuracy_score(y, y_pred))

print("\nClassification Report: ")
print(classification_report(y, y_pred))
# Out:
# Predicted Anomalous Data Points:  47
# Predicted Non Anomalous Data Points:  28434
# =======================================================
# Number of misclassified data points:  63
#
# Accuracy Score : 0.9977879990168884
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     28435
#            1       0.32      0.33      0.32        46
#
#     accuracy                           1.00     28481
#    macro avg       0.66      0.66      0.66     28481
# weighted avg       1.00      1.00      1.00     28481

# %%
# adding the predicted y to the sampled dataset
sampled_data["y_pred_iso"] = y_pred
print(sampled_data["y_pred_iso"].value_counts())
# Out:
# 0    28434
# 1       47
# Name: y_pred_iso, dtype: int64

# %%
# plotting normal and fraud data points

fig = plt.figure(figsize=(14, 5))

# Isolation Forest Plot
plt.subplot(1, 2, 1)
anomaly_df = sampled_data.loc[sampled_data["y_pred_iso"] == 1, ["Time", "Amount"]]
plt.plot(sampled_data["Time"], sampled_data["Amount"], color="blue")
plt.scatter(anomaly_df["Time"], anomaly_df["Amount"], color="red")
plt.title("Anomalies Detected Using Isolation Forest (in Red)")
plt.xlabel("Time (seconds)")
plt.ylabel("Amount")

# Original data plot
plt.subplot(1, 2, 2)
anomaly_df = sampled_data.loc[sampled_data["Class"] == 1, ["Time", "Amount"]]
plt.plot(sampled_data["Time"], sampled_data["Amount"], color="green")
plt.scatter(anomaly_df["Time"], anomaly_df["Amount"], color="red")
plt.title("Original Anomalies (in Red)")
plt.xlabel("Time (seconds)")
plt.ylabel("Amount")

plt.show()

# %% [markdown]
# ## 2. Local Outlier Factor (Unsupervised Outlier Detection)
# n_neighbors: int, default=20 Number of neighbors to use by default for kneighbors queries. If n_neighbors is larger than the number of samples provided, all samples will be used.
#
# leaf_size: int, default=30 Leaf size passed to BallTree or KDTree. This can affect the speed of the construction and query, as well as the memory required to store the tree. The optimal value depends on the nature of the problem.
#
# metric: str or callable, default=’minkowski’ metric used for the distance computation. Any metric from scikit-learn or scipy.spatial.distance can be used.
#
# p: int, default=2 Parameter for the Minkowski metric from sklearn.metrics.pairwise.pairwise_distances. When p = 1, this is equivalent to using manhattan_distance (l1), and euclidean_distance (l2) for p = 2. For arbitrary p, minkowski_distance (l_p) is used.

# %%
from sklearn.neighbors import LocalOutlierFactor

lof = LocalOutlierFactor(
    n_neighbors=20,
    algorithm="auto",
    leaf_size=30,
    metric="minkowski",
    p=2,
    metric_params=None,
    contamination=outlier_fraction,
)

y_pred_lof = lof.fit_predict(X)

print("Predicted Anomalous Data Points: ", len(y_pred_lof[y_pred_lof == -1]))
print("Predicted Non Anomalous Data Points: ", len(y_pred_lof[y_pred_lof == 1]))
print("================================================================")


# replacing -1 by 1 and 1 by 0
y_pred_lof[y_pred_lof == 1] = 0
y_pred_lof[y_pred_lof == -1] = 1

# evaluation
print("Number of misclassified data points: ", (y_pred_lof != y).sum())
print("\nAccuracy Score :", accuracy_score(y, y_pred_lof))

print("\nClassification Report: ")
print(classification_report(y, y_pred_lof))
# Out:
# Predicted Anomalous Data Points:  47
# Predicted Non Anomalous Data Points:  28434
# ================================================================
# Number of misclassified data points:  91
#
# Accuracy Score : 0.9968048874688389
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     28435
#            1       0.02      0.02      0.02        46
#
#     accuracy                           1.00     28481
#    macro avg       0.51      0.51      0.51     28481
# weighted avg       1.00      1.00      1.00     28481

# %%
# adding the predicted y to the sampled dataset
sampled_data["y_pred_lof"] = y_pred_lof
print(sampled_data["y_pred_lof"].value_counts())
# Out:
# 0    28434
# 1       47
# Name: y_pred_lof, dtype: int64

# %%
# plotting normal and fraud data points

fig = plt.figure(figsize=(14, 5))

# LOF Plot
plt.subplot(1, 2, 1)
anomaly_df = sampled_data.loc[sampled_data["y_pred_lof"] == 1, ["Time", "Amount"]]
plt.plot(sampled_data["Time"], sampled_data["Amount"], color="blue")
plt.scatter(anomaly_df["Time"], anomaly_df["Amount"], color="red")
plt.title("Anomalies Detected Using LOF (in Red)")
plt.xlabel("Time (seconds)")
plt.ylabel("Amount")

# Original Plot
plt.subplot(1, 2, 2)
anomaly_df = sampled_data.loc[sampled_data["Class"] == 1, ["Time", "Amount"]]
plt.plot(sampled_data["Time"], sampled_data["Amount"], color="green")
plt.scatter(anomaly_df["Time"], anomaly_df["Amount"], color="red")
plt.title("Original Anomalies (in Red)")
plt.xlabel("Time (seconds)")
plt.ylabel("Amount")

plt.show()

# %% [markdown]
# ## 3. Deep Learning - AutoEncoders

# %%
# creating a smaller sample for handling imbalanced dataset.

normal_trans = df[df["Class"] == 0].sample(2000)
fraud_trans = df[df["Class"] == 1]
dl_sample_data = normal_trans.append(fraud_trans).reset_index(drop=True)

print("Target Class Value Counts: ")
print(dl_sample_data["Class"].value_counts())
# Out:
# Target Class Value Counts:
# 0    2000
# 1     492
# Name: Class, dtype: int64

# %%
# splitting the data

X = dl_sample_data.drop("Class", axis=1)
y = dl_sample_data["Class"]

print("X Shape: ", X.shape)
print("y Shape: ", y.shape)
# Out:
# X Shape:  (2492, 30)
# y Shape:  (2492,)

# %% [markdown]
# ### Visualize the data with t-SNE
# TNSE(t-distributed Stochastic Neighbor Embedding) is one of the dimensionality reduction method other than PCA and SVD. This will supress some noise and speed up the computation of pairwise distance between samples.

# %%
def dimensionality_plot(X, y):

    #     sns.set(style='whitegrid', palette='muted')

    # Initializing TSNE object with 2 principal components
    tsne = TSNE(n_components=2, random_state=42)

    # Fitting the data
    X_trans = tsne.fit_transform(X)

    plt.figure(figsize=(10, 6))

    plt.scatter(
        X_trans[np.where(y == 0), 0],
        X_trans[np.where(y == 0), 1],
        marker="o",
        color="b",
        linewidth=1,
        alpha=0.8,
        label="Normal",
    )

    plt.scatter(
        X_trans[np.where(y == 1), 0],
        X_trans[np.where(y == 1), 1],
        marker="o",
        color="r",
        linewidth=1,
        alpha=0.8,
        label="Fraud",
    )

    plt.legend(loc="best")

    plt.show()

# %%
# plotting the dimensionality_plot for original data

dimensionality_plot(X, y)

# %%
# scaling the data

scaler = StandardScaler().fit_transform(X)

# scaled data
X_scaled_normal = scaler[y == 0]
X_scaled_fraud = scaler[y == 1]

# %%
# setting up the input shape (equal to number of features)
input_layer = Input(shape=(X.shape[1],))

# building the encoder network
encoded = Dense(100, activation="tanh", activity_regularizer=regularizers.l1(10e-5))(
    input_layer
)
encoded = Dense(50, activation="tanh", activity_regularizer=regularizers.l1(10e-5))(
    encoded
)
encoded = Dense(25, activation="tanh", activity_regularizer=regularizers.l1(10e-5))(
    encoded
)
encoded = Dense(12, activation="tanh", activity_regularizer=regularizers.l1(10e-5))(
    encoded
)
encoded = Dense(6, activation="relu")(encoded)

# building the decoder network
decoded = Dense(12, activation="tanh")(encoded)
decoded = Dense(25, activation="tanh")(decoded)
decoded = Dense(50, activation="tanh")(decoded)
decoded = Dense(100, activation="tanh")(decoded)

output_layer = Dense(X.shape[1], activation="sigmoid")(decoded)

# creating the model
autoencoder = Model(input_layer, output_layer)

autoencoder.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 30)]              0
# _________________________________________________________________
# dense (Dense)                (None, 100)               3100
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_2 (Dense)              (None, 25)                1275
# _________________________________________________________________
# dense_3 (Dense)              (None, 12)                312
# _________________________________________________________________
# dense_4 (Dense)              (None, 6)                 78
# _________________________________________________________________
# dense_5 (Dense)              (None, 12)                84
# _________________________________________________________________
# dense_6 (Dense)              (None, 25)                325
# _________________________________________________________________
# dense_7 (Dense)              (None, 50)                1300
# _________________________________________________________________
# dense_8 (Dense)              (None, 100)               5100
# _________________________________________________________________
# dense_9 (Dense)              (None, 30)                3030
# =================================================================
# Total params: 19,654
# Trainable params: 19,654
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compiling the auto encoder model
autoencoder.compile(optimizer="adam", loss="mse")

# training the auto encoder model on non fraud data (we don't need too many observations for model learning in this case)
history = autoencoder.fit(
    X_scaled_normal,
    X_scaled_normal,
    batch_size=32,
    epochs=50,
    shuffle=True,
    validation_split=0.20,
)
# Out:
# Epoch 1/50
# 50/50 [==============================] - 1s 13ms/step - loss: 0.5220 - val_loss: 0.4522
# Epoch 2/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.4570 - val_loss: 0.4333
# Epoch 3/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.4361 - val_loss: 0.4147
# Epoch 4/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.4218 - val_loss: 0.4053
# Epoch 5/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.4142 - val_loss: 0.3996
# Epoch 6/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.4084 - val_loss: 0.3957
# Epoch 7/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.4042 - val_loss: 0.3919
# Epoch 8/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3999 - val_loss: 0.3890
# Epoch 9/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3961 - val_loss: 0.3841
# Epoch 10/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3917 - val_loss: 0.3811
# Epoch 11/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3884 - val_loss: 0.3784
# Epoch 12/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3859 - val_loss: 0.3758
# Epoch 13/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3840 - val_loss: 0.3755
# Epoch 14/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3819 - val_loss: 0.3722
# Epoch 15/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3799 - val_loss: 0.3725
# Epoch 16/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3785 - val_loss: 0.3727
# Epoch 17/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3774 - val_loss: 0.3711
# Epoch 18/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3762 - val_loss: 0.3698
# Epoch 19/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3749 - val_loss: 0.3682
# Epoch 20/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3738 - val_loss: 0.3669
# Epoch 21/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3725 - val_loss: 0.3685
# Epoch 22/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3714 - val_loss: 0.3663
# Epoch 23/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3706 - val_loss: 0.3657
# Epoch 24/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3695 - val_loss: 0.3659
# Epoch 25/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3686 - val_loss: 0.3658
# Epoch 26/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3682 - val_loss: 0.3659
# Epoch 27/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3673 - val_loss: 0.3625
# Epoch 28/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3663 - val_loss: 0.3623
# Epoch 29/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3661 - val_loss: 0.3625
# Epoch 30/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3657 - val_loss: 0.3622
# Epoch 31/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3643 - val_loss: 0.3644
# Epoch 32/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3644 - val_loss: 0.3609
# Epoch 33/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3632 - val_loss: 0.3599
# Epoch 34/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3623 - val_loss: 0.3619
# Epoch 35/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3629 - val_loss: 0.3602
# Epoch 36/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3626 - val_loss: 0.3616
# Epoch 37/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3621 - val_loss: 0.3628
# Epoch 38/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3609 - val_loss: 0.3607
# Epoch 39/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3605 - val_loss: 0.3604
# Epoch 40/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3597 - val_loss: 0.3595
# Epoch 41/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3593 - val_loss: 0.3585
# Epoch 42/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3587 - val_loss: 0.3577
# Epoch 43/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3583 - val_loss: 0.3581
# Epoch 44/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3576 - val_loss: 0.3580
# Epoch 45/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3567 - val_loss: 0.3570
# Epoch 46/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3560 - val_loss: 0.3562
# Epoch 47/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3559 - val_loss: 0.3575
# Epoch 48/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3555 - val_loss: 0.3559
# Epoch 49/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3552 - val_loss: 0.3560
# Epoch 50/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3551 - val_loss: 0.3553

# %%
# Loss curve

plt.figure(figsize=[6, 4])
plt.plot(history.history["loss"], "black", linewidth=2.0)
plt.plot(history.history["val_loss"], "green", linewidth=2.0)
plt.legend(["Training Loss", "Validation Loss"], fontsize=14)
plt.xlabel("Epochs", fontsize=10)
plt.ylabel("Loss", fontsize=10)
plt.title("Loss Curves", fontsize=12)
# Out:
# Text(0.5, 1.0, 'Loss Curves')

# %%
# creating the sequential model and adding the trainined weights till the fifth layer (till where the latent representation exists)

latent_model = Sequential()
latent_model.add(autoencoder.layers[0])
latent_model.add(autoencoder.layers[1])
latent_model.add(autoencoder.layers[2])
latent_model.add(autoencoder.layers[3])
latent_model.add(autoencoder.layers[4])

# %%
# generating the hidden representation of the 2 classes

normal_datapoints = latent_model.predict(X_scaled_normal)
fraud_datapoints = latent_model.predict(X_scaled_fraud)

# creating a dataframe of latent representation of the data

encoded_X = np.append(normal_datapoints, fraud_datapoints, axis=0)

y_normal = np.zeros(normal_datapoints.shape[0])
y_fraud = np.ones(fraud_datapoints.shape[0])
encoded_y = np.append(y_normal, y_fraud, axis=0)

# %%
# plotting the TSNE function again to visualize the latent data

dimensionality_plot(encoded_X, encoded_y)

# %%
# splitting the data into train and test

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# splitting the encoded data
X_enc_train, X_enc_test, y_enc_train, y_enc_test = train_test_split(
    encoded_X, encoded_y, test_size=0.25
)

print(
    f"Encoded train data X: {X_enc_train.shape}, Y: {y_enc_train.shape}, X_test :{X_enc_test.shape}, Y_test: {y_enc_test.shape}"
)
print(
    f"Actual train & test data X: {X_train.shape}, Y: {X_train.shape}, X_test :{X_test.shape}, Y_test: {y_test.shape}"
)
# Out:
# Encoded train data X: (1869, 12), Y: (1869,), X_test :(623, 12), Y_test: (623,)
# Actual train & test data X: (1869, 30), Y: (1869, 30), X_test :(623, 30), Y_test: (623,)

# %%
# applying support vector classifier on the encoded data

svc_clf = SVC(probability=True)

svc_clf.fit(X_enc_train, y_enc_train)

svc_predictions = svc_clf.predict(X_enc_test)

# y_probability
y_proba = svc_clf.predict_proba(X_enc_test)[:, 1]

# precision recall score
average_precision = average_precision_score(y_enc_test, y_proba)

print("Accuracy of SVC {:.2f}".format(accuracy_score(y_enc_test, svc_predictions)))
print("==============================================================")

print(f"ROC-AUC Score: {roc_auc_score(y_enc_test, y_proba):.2f}")
print("==============================================================")

print(f"Average Precision-Recall Score: {average_precision:.2f}")
print("==============================================================")

print(
    "\nClassification report \n {0}".format(
        classification_report(y_enc_test, svc_predictions)
    )
)
# Out:
# Accuracy of SVC 0.96
# ==============================================================
# ROC-AUC Score: 0.96
# ==============================================================
# Average Precision-Recall Score: 0.93
# ==============================================================
#
# Classification report
#                precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97       516
#          1.0       0.98      0.76      0.85       107
#
#     accuracy                           0.96       623
#    macro avg       0.96      0.88      0.91       623
# weighted avg       0.96      0.96      0.95       623

# %%
# applying logistic regression model on the encoded data

lr_clf = LogisticRegression()

lr_clf.fit(X_enc_train, y_enc_train)

predictions = lr_clf.predict(X_enc_test)

# y_probability
y_proba = lr_clf.predict_proba(X_enc_test)[:, 1]

# precision recall score
average_precision = average_precision_score(y_enc_test, y_proba)

print("Accuracy score is : {:.2f}".format(accuracy_score(y_enc_test, predictions)))
print("==============================================================")

print(f"ROC-AUC Score: {roc_auc_score(y_enc_test, y_proba):.2f}")
print("==============================================================")

print(f"Average Precision-Recall Score: {average_precision:.2f}")
print("==============================================================")

print(
    "\nClassification report \n {0}".format(
        classification_report(y_enc_test, predictions)
    )
)
# Out:
# Accuracy score is : 0.95
# ==============================================================
# ROC-AUC Score: 0.95
# ==============================================================
# Average Precision-Recall Score: 0.91
# ==============================================================
#
# Classification report
#                precision    recall  f1-score   support
#
#          0.0       0.95      0.99      0.97       516
#          1.0       0.93      0.76      0.84       107
#
#     accuracy                           0.95       623
#    macro avg       0.94      0.87      0.90       623
# weighted avg       0.95      0.95      0.95       623

# %% [markdown]
# ## 4. CNN - Convolution Neural Network

# %%
print(X.shape)
print(y.shape)
# Out:
# (2492, 30)
# (2492,)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

print("X_train Shape", X_train.shape)
print("X_test Shape", X_test.shape)
print("y_train Shape", y_train.shape)
print("y_test Shape", y_test.shape)

# scaling the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)
# Out:
# X_train Shape (1869, 30)
# X_test Shape (623, 30)
# y_train Shape (1869,)
# y_test Shape (623,)

# %%
# changing the shape of the data so that the model can process it
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# verifying the changed shape
X_train.shape, X_test.shape
# Out:
# ((1869, 30, 1), (623, 30, 1))

# %%
model = Sequential()

model.add(
    Conv1D(filters=32, kernel_size=2, activation="relu", input_shape=X_train[0].shape)
)
model.add(BatchNormalization())
model.add(Dropout(0.1))

model.add(Conv1D(filters=64, kernel_size=2, activation="relu"))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Conv1D(filters=128, kernel_size=2, activation="relu"))
model.add(BatchNormalization())
model.add(Dropout(0.3))

model.add(Flatten())
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(1, activation="sigmoid"))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 29, 32)            96
# _________________________________________________________________
# batch_normalization (BatchNo (None, 29, 32)            128
# _________________________________________________________________
# dropout (Dropout)            (None, 29, 32)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 28, 64)            4160
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 28, 64)            256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 28, 64)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 27, 128)           16512
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 27, 128)           512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 27, 128)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 3456)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                221248
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 242,977
# Trainable params: 242,529
# Non-trainable params: 448
# _________________________________________________________________

# %%
model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy", keras.metrics.AUC()],
)

# fitting the model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50)
# Out:
# Epoch 1/50
# 59/59 [==============================] - 2s 33ms/step - loss: 0.2547 - accuracy: 0.9369 - auc: 0.9432 - val_loss: 0.3474 - val_accuracy: 0.9053 - val_auc: 0.9763
# Epoch 2/50
# 59/59 [==============================] - 1s 16ms/step - loss: 0.1169 - accuracy: 0.9658 - auc: 0.9757 - val_loss: 0.2601 - val_accuracy: 0.9021 - val_auc: 0.9711
# Epoch 3/50
# 59/59 [==============================] - 1s 17ms/step - loss: 0.1128 - accuracy: 0.9679 - auc: 0.9793 - val_loss: 0.1843 - val_accuracy: 0.9149 - val_auc: 0.9740
# Epoch 4/50
# 59/59 [==============================] - 1s 18ms/step - loss: 0.1192 - accuracy: 0.9674 - auc: 0.9771 - val_loss: 0.1275 - val_accuracy: 0.9502 - val_auc: 0.9797
# Epoch 5/50
# 59/59 [==============================] - 1s 17ms/step - loss: 0.1025 - accuracy: 0.9674 - auc: 0.9828 - val_loss: 0.1045 - val_accuracy: 0.9663 - val_auc: 0.9772
# Epoch 6/50
# 59/59 [==============================] - 1s 17ms/step - loss: 0.0996 - accuracy: 0.9700 - auc: 0.9796 - val_loss: 0.1043 - val_accuracy: 0.9695 - val_auc: 0.9780
# Epoch 7/50
# 59/59 [==============================] - 1s 18ms/step - loss: 0.0986 - accuracy: 0.9695 - auc: 0.9844 - val_loss: 0.1049 - val_accuracy: 0.9743 - val_auc: 0.9756
# Epoch 8/50
# 59/59 [==============================] - 1s 18ms/step - loss: 0.0672 - accuracy: 0.9765 - auc: 0.9916 - val_loss: 0.1148 - val_accuracy: 0.9711 - val_auc: 0.9719
# Epoch 9/50
# 59/59 [==============================] - 1s 16ms/step - loss: 0.0817 - accuracy: 0.9759 - auc: 0.9890 - val_loss: 0.1164 - val_accuracy: 0.9711 - val_auc: 0.9763
# Epoch 10/50
# 59/59 [==============================] - 1s 18ms/step - loss: 0.0777 - accuracy: 0.9797 - auc: 0.9896 - val_loss: 0.1217 - val_accuracy: 0.9647 - val_auc: 0.9771
# Epoch 11/50
# 59/59 [==============================] - 1s 18ms/step - loss: 0.0638 - accuracy: 0.9797 - auc: 0.9914 - val_loss: 0.1167 - val_accuracy: 0.9743 - val_auc: 0.9762
# Epoch 12/50
# 59/59 [==============================] - 1s 17ms/step - loss: 0.0643 - accuracy: 0.9770 - auc: 0.9923 - val_loss: 0.1123 - val_accuracy: 0.9727 - val_auc: 0.9794
# Epoch 13/50
# 59/59 [==============================] - 1s 18ms/step - loss: 0.0564 - accuracy: 0.9813 - auc: 0.9922 - val_loss: 0.1118 - val_accuracy: 0.9743 - val_auc: 0.9799
# Epoch 14/50
# 59/59 [==============================] - 1s 16ms/step - loss: 0.0536 - accuracy: 0.9781 - auc: 0.9965 - val_loss: 0.1171 - val_accuracy: 0.9727 - val_auc: 0.9795
# Epoch 15/50
# 59/59 [==============================] - 1s 16ms/step - loss: 0.0579 - accuracy: 0.9775 - auc: 0.9941 - val_loss: 0.1170 - val_accuracy: 0.9743 - val_auc: 0.9797
# Epoch 16/50
# 59/59 [==============================] - 1s 16ms/step - loss: 0.0479 - accuracy: 0.9813 - auc: 0.9948 - val_loss: 0.1301 - val_accuracy: 0.9679 - val_auc: 0.9762
# Epoch 17/50
# 59/59 [==============================] - 1s 17ms/step - loss: 0.0450 - accuracy: 0.9861 - auc: 0.9964 - val_loss: 0.1350 - val_accuracy: 0.9727 - val_auc: 0.9724
# Epoch 18/50
# 59/59 [==============================] - 1s 18ms/step - loss: 0.0463 - accuracy: 0.9866 - auc: 0.9949 - val_loss: 0.1522 - val_accuracy: 0.9679 - val_auc: 0.9687
# Epoch 19/50
# 59/59 [==============================] - 1s 17ms/step - loss: 0.0397 - accuracy: 0.9877 - auc: 0.9953 - val_loss: 0.1401 - val_accuracy: 0.9663 - val_auc: 0.9777
# Epoch 20/50
# 59/59 [==============================] - 1s 17ms/step - loss: 0.0460 - accuracy: 0.9856 - auc: 0.9974 - val_loss: 0.1560 - val_accuracy: 0.9711 - val_auc: 0.9692
# Epoch 21/50
# 59/59 [==============================] - 1s 15ms/step - loss: 0.0435 - accuracy: 0.9850 - auc: 0.9965 - val_loss: 0.1524 - val_accuracy: 0.9727 - val_auc: 0.9727
# Epoch 22/50
# 59/59 [==============================] - 1s 17ms/step - loss: 0.0440 - accuracy: 0.9839 - auc: 0.9953 - val_loss: 0.1451 - val_accuracy: 0.9727 - val_auc: 0.9756
# Epoch 23/50
# 59/59 [==============================] - 1s 15ms/step - loss: 0.0323 - accuracy: 0.9872 - auc: 0.9989 - val_loss: 0.1529 - val_accuracy: 0.9743 - val_auc: 0.9779
# Epoch 24/50
# 59/59 [==============================] - 1s 17ms/step - loss: 0.0362 - accuracy: 0.9850 - auc: 0.9986 - val_loss: 0.1586 - val_accuracy: 0.9727 - val_auc: 0.9701
# Epoch 25/50
# 59/59 [==============================] - 1s 17ms/step - loss: 0.0432 - accuracy: 0.9882 - auc: 0.9951 - val_loss: 0.1270 - val_accuracy: 0.9711 - val_auc: 0.9802
# Epoch 26/50
# 59/59 [==============================] - 1s 17ms/step - loss: 0.0498 - accuracy: 0.9823 - auc: 0.9974 - val_loss: 0.1561 - val_accuracy: 0.9663 - val_auc: 0.9733
# Epoch 27/50
# 59/59 [==============================] - 1s 17ms/step - loss: 0.0401 - accuracy: 0.9839 - auc: 0.9960 - val_loss: 0.1427 - val_accuracy: 0.9663 - val_auc: 0.9730
# Epoch 28/50
# 59/59 [==============================] - 1s 18ms/step - loss: 0.0391 - accuracy: 0.9850 - auc: 0.9972 - val_loss: 0.1550 - val_accuracy: 0.9631 - val_auc: 0.9764
# Epoch 29/50
# 59/59 [==============================] - 1s 15ms/step - loss: 0.0311 - accuracy: 0.9872 - auc: 0.9989 - val_loss: 0.1707 - val_accuracy: 0.9743 - val_auc: 0.9774
# Epoch 30/50
# 59/59 [==============================] - 1s 17ms/step - loss: 0.0372 - accuracy: 0.9893 - auc: 0.9959 - val_loss: 0.1799 - val_accuracy: 0.9695 - val_auc: 0.9700
# Epoch 31/50
# 59/59 [==============================] - 1s 17ms/step - loss: 0.0306 - accuracy: 0.9882 - auc: 0.9989 - val_loss: 0.1648 - val_accuracy: 0.9695 - val_auc: 0.9740
# Epoch 32/50
# 59/59 [==============================] - 1s 16ms/step - loss: 0.0256 - accuracy: 0.9904 - auc: 0.9993 - val_loss: 0.1779 - val_accuracy: 0.9695 - val_auc: 0.9783
# Epoch 33/50
# 59/59 [==============================] - 1s 16ms/step - loss: 0.0323 - accuracy: 0.9872 - auc: 0.9977 - val_loss: 0.1745 - val_accuracy: 0.9663 - val_auc: 0.9744
# Epoch 34/50
# 59/59 [==============================] - 1s 17ms/step - loss: 0.0306 - accuracy: 0.9845 - auc: 0.9990 - val_loss: 0.1737 - val_accuracy: 0.9663 - val_auc: 0.9777
# Epoch 35/50
# 59/59 [==============================] - 1s 16ms/step - loss: 0.0267 - accuracy: 0.9893 - auc: 0.9980 - val_loss: 0.1907 - val_accuracy: 0.9679 - val_auc: 0.9706
# Epoch 36/50
# 59/59 [==============================] - 1s 15ms/step - loss: 0.0360 - accuracy: 0.9877 - auc: 0.9985 - val_loss: 0.1897 - val_accuracy: 0.9663 - val_auc: 0.9761
# Epoch 37/50
# 59/59 [==============================] - 1s 17ms/step - loss: 0.0279 - accuracy: 0.9888 - auc: 0.9991 - val_loss: 0.1840 - val_accuracy: 0.9679 - val_auc: 0.9702
# Epoch 38/50
# 59/59 [==============================] - 1s 17ms/step - loss: 0.0293 - accuracy: 0.9909 - auc: 0.9965 - val_loss: 0.1601 - val_accuracy: 0.9711 - val_auc: 0.9782
# Epoch 39/50
# 59/59 [==============================] - 1s 17ms/step - loss: 0.0207 - accuracy: 0.9925 - auc: 0.9996 - val_loss: 0.2021 - val_accuracy: 0.9679 - val_auc: 0.9733
# Epoch 40/50
# 59/59 [==============================] - 1s 16ms/step - loss: 0.0241 - accuracy: 0.9914 - auc: 0.9981 - val_loss: 0.1870 - val_accuracy: 0.9663 - val_auc: 0.9697
# Epoch 41/50
# 59/59 [==============================] - 1s 17ms/step - loss: 0.0202 - accuracy: 0.9925 - auc: 0.9996 - val_loss: 0.1977 - val_accuracy: 0.9695 - val_auc: 0.9660
# Epoch 42/50
# 59/59 [==============================] - 1s 19ms/step - loss: 0.0171 - accuracy: 0.9952 - auc: 0.9996 - val_loss: 0.2001 - val_accuracy: 0.9695 - val_auc: 0.9700
# Epoch 43/50
# 59/59 [==============================] - 1s 18ms/step - loss: 0.0207 - accuracy: 0.9930 - auc: 0.9969 - val_loss: 0.1957 - val_accuracy: 0.9695 - val_auc: 0.9765
# Epoch 44/50
# 59/59 [==============================] - 1s 17ms/step - loss: 0.0170 - accuracy: 0.9936 - auc: 0.9997 - val_loss: 0.2081 - val_accuracy: 0.9695 - val_auc: 0.9699
# Epoch 45/50
# 59/59 [==============================] - 1s 17ms/step - loss: 0.0262 - accuracy: 0.9904 - auc: 0.9993 - val_loss: 0.2184 - val_accuracy: 0.9695 - val_auc: 0.9694
# Epoch 46/50
# 59/59 [==============================] - 1s 18ms/step - loss: 0.0297 - accuracy: 0.9893 - auc: 0.9953 - val_loss: 0.2025 - val_accuracy: 0.9631 - val_auc: 0.9757
# Epoch 47/50
# 59/59 [==============================] - 1s 18ms/step - loss: 0.0216 - accuracy: 0.9909 - auc: 0.9995 - val_loss: 0.2083 - val_accuracy: 0.9695 - val_auc: 0.9777
# Epoch 48/50
# 59/59 [==============================] - 1s 18ms/step - loss: 0.0282 - accuracy: 0.9904 - auc: 0.9979 - val_loss: 0.1991 - val_accuracy: 0.9727 - val_auc: 0.9739
# Epoch 49/50
# 59/59 [==============================] - 1s 19ms/step - loss: 0.0203 - accuracy: 0.9920 - auc: 0.9995 - val_loss: 0.2264 - val_accuracy: 0.9663 - val_auc: 0.9696ss: 0.0202 - accuracy
# Epoch 50/50
# 59/59 [==============================] - 1s 19ms/step - loss: 0.0208 - accuracy: 0.9898 - auc: 0.9983 - val_loss: 0.2131 - val_accuracy: 0.9711 - val_auc: 0.9656

# %%
# Loss curve

plt.figure(figsize=[6, 4])
plt.plot(history.history["loss"], "black", linewidth=2.0)
plt.plot(history.history["val_loss"], "green", linewidth=2.0)
plt.legend(["Training Loss", "Validation Loss"], fontsize=14)
plt.xlabel("Epochs", fontsize=10)
plt.ylabel("Loss", fontsize=10)
plt.title("Loss Curves", fontsize=12)
# Out:
# Text(0.5, 1.0, 'Loss Curves')

# %%
# Accuracy curve

plt.figure(figsize=[6, 4])
plt.plot(history.history["accuracy"], "black", linewidth=2.0)
plt.plot(history.history["val_accuracy"], "blue", linewidth=2.0)
plt.legend(["Training Accuracy", "Validation Accuracy"], fontsize=14)
plt.xlabel("Epochs", fontsize=10)
plt.ylabel("Accuracy", fontsize=10)
plt.title("Accuracy Curves", fontsize=12)
# Out:
# Text(0.5, 1.0, 'Accuracy Curves')

# %%
# AUC curve

plt.figure(figsize=[6, 4])
plt.plot(history.history["auc"], "black", linewidth=2.0)
plt.plot(history.history["val_auc"], "orange", linewidth=2.0)
plt.legend(["Training AUC", "Validation AUC"], fontsize=14)
plt.xlabel("Epochs", fontsize=10)
plt.ylabel("AUC", fontsize=10)
plt.title("AUC Curves", fontsize=12)
# Out:
# Text(0.5, 1.0, 'AUC Curves')

# %%
print("Average AUC Score: ", np.mean(history.history["val_auc"]))
# Out:
# Average AUC Score:  0.9743841969966889
